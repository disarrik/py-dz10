# %%
from pyspark.sql import SparkSession
from time import process_time
import pyspark.sql.functions as F
from pyspark.sql.functions import col

# %%
spark = SparkSession.builder \
    .config('spark.pyspark.python', '/usr/local/bin/python3.8') \
    .config('spark.pyspark.driver.python', '/usr/local/bin/python3.8') \
    .appName('dz10') \
    .master('local') \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/01 19:11:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import pandas as pd
from sdv.single_table import GaussianCopulaSynthesizer
from sdv.metadata import SingleTableMetadata

def generate_data(spark: SparkSession, csv_path: str, n, sep=','):
    df = pd.read_csv(csv_path, sep=sep)
    metadata = SingleTableMetadata()
    metadata.detect_from_dataframe(df)
    synthesizer = GaussianCopulaSynthesizer(metadata)
    synthesizer.fit(df)
    synthetic_data = synthesizer.sample(num_rows=n)
    return spark.createDataFrame(synthetic_data)
# Out:
# 24/12/01 19:11:16 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
import time

for caching in (False, True):
    def do():
        data = generate_data(spark, 'electronic_devices.csv', 1000000)
        dt = data \
            .filter(col('purchase_date') == '2024-09-03') \
            .filter(F.size(F.split(col('addons'), ',')) == 1)
        if caching:
            dt = dt.cache()
        for group in (['gender'], ['age'], ['gender', 'age']): 
            for column in ('total_price', 'unit_price'):
                result = dt.groupBy(group) \
                    .agg(F.min(column), F.max(column)) \
                    .collect()
                print(result)
                
    begin = time.process_time()
    do()
    total = time.process_time() - begin
    print(f"processed in {total} caching={caching}")
# Out:
# /Users/disarra/hse/python/dz10/spark/lib/python3.8/site-packages/sdv/single_table/base.py:119: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /Users/disarra/hse/python/dz10/spark/lib/python3.8/site-packages/sdv/single_table/base.py:104: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# 24/12/01 19:35:13 WARN TaskSetManager: Stage 93 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# 24/12/01 19:35:17 WARN TaskSetManager: Stage 96 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(gender='Female', min(total_price)=25.88, max(total_price)=11396.8), Row(gender='Male', min(total_price)=21.96, max(total_price)=11396.8)]
# [Row(gender='Female', min(unit_price)=123.81, max(unit_price)=1139.68), Row(gender='Male', min(unit_price)=123.85, max(unit_price)=1139.67)]
# 24/12/01 19:35:21 WARN TaskSetManager: Stage 99 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# 24/12/01 19:35:25 WARN TaskSetManager: Stage 102 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(age=26, min(total_price)=754.6, max(total_price)=9026.8), Row(age=29, min(total_price)=407.94, max(total_price)=7546.81), Row(age=65, min(total_price)=87.32, max(total_price)=6887.02), Row(age=19, min(total_price)=105.46, max(total_price)=6611.77), Row(age=54, min(total_price)=286.38, max(total_price)=9822.92), Row(age=22, min(total_price)=27.63, max(total_price)=8519.85), Row(age=77, min(total_price)=51.63, max(total_price)=7630.14), Row(age=34, min(total_price)=105.25, max(total_price)=8927.99), Row(age=50, min(total_price)=155.61, max(total_price)=8839.47), Row(age=57, min(total_price)=190.88, max(total_price)=9969.88), Row(age=32, min(total_price)=28.36, max(total_price)=9601.93), Row(age=43, min(total_price)=463.07, max(total_price)=9534.8), Row(age=31, min(total_price)=36.98, max(total_price)=8218.8), Row(age=39, min(total_price)=202.87, max(total_price)=7198.22), Row(age=25, min(total_price)=114.31, max(total_price)=7538.19), Row(age=71, min(total_price)=265.0, max(total_price)=11396.8), Row(age=68, min(total_price)=294.61, max(total_price)=11396.8), Row(age=72, min(total_price)=171.06, max(total_price)=11396.8), Row(age=58, min(total_price)=118.44, max(total_price)=10680.56), Row(age=27, min(total_price)=824.7, max(total_price)=8764.94), Row(age=63, min(total_price)=146.84, max(total_price)=9519.21), Row(age=56, min(total_price)=41.75, max(total_price)=11396.8), Row(age=51, min(total_price)=27.15, max(total_price)=8545.02), Row(age=52, min(total_price)=87.71, max(total_price)=11396.8), Row(age=79, min(total_price)=38.95, max(total_price)=8600.45), Row(age=41, min(total_price)=381.33, max(total_price)=7380.3), Row(age=28, min(total_price)=154.54, max(total_price)=8068.06), Row(age=33, min(total_price)=25.88, max(total_price)=9451.08), Row(age=67, min(total_price)=33.73, max(total_price)=8857.35), Row(age=48, min(total_price)=85.17, max(total_price)=10852.25), Row(age=44, min(total_price)=21.96, max(total_price)=9001.28), Row(age=61, min(total_price)=68.76, max(total_price)=10495.26), Row(age=37, min(total_price)=37.77, max(total_price)=11396.8), Row(age=55, min(total_price)=57.88, max(total_price)=11396.8), Row(age=74, min(total_price)=55.8, max(total_price)=8158.27), Row(age=62, min(total_price)=326.52, max(total_price)=10588.37), Row(age=49, min(total_price)=128.06, max(total_price)=10938.94), Row(age=35, min(total_price)=36.32, max(total_price)=8286.73), Row(age=80, min(total_price)=112.97, max(total_price)=4658.29), Row(age=66, min(total_price)=118.58, max(total_price)=9572.95), Row(age=76, min(total_price)=110.53, max(total_price)=10767.48), Row(age=36, min(total_price)=117.61, max(total_price)=11396.8), Row(age=75, min(total_price)=227.81, max(total_price)=9002.88), Row(age=78, min(total_price)=62.88, max(total_price)=9987.69), Row(age=69, min(total_price)=36.64, max(total_price)=10950.05), Row(age=21, min(total_price)=27.03, max(total_price)=8580.62), Row(age=59, min(total_price)=141.69, max(total_price)=9719.13), Row(age=38, min(total_price)=121.99, max(total_price)=9426.53), Row(age=42, min(total_price)=114.51, max(total_price)=10195.57), Row(age=73, min(total_price)=251.71, max(total_price)=9963.78), Row(age=30, min(total_price)=111.7, max(total_price)=7367.7), Row(age=23, min(total_price)=323.85, max(total_price)=10677.81), Row(age=46, min(total_price)=72.6, max(total_price)=11396.8), Row(age=20, min(total_price)=78.0, max(total_price)=9777.08), Row(age=70, min(total_price)=79.99, max(total_price)=9933.12), Row(age=60, min(total_price)=22.81, max(total_price)=11396.8), Row(age=40, min(total_price)=76.38, max(total_price)=9571.2), Row(age=64, min(total_price)=44.74, max(total_price)=9172.57), Row(age=47, min(total_price)=163.48, max(total_price)=11396.8), Row(age=53, min(total_price)=99.34, max(total_price)=7179.24), Row(age=45, min(total_price)=55.41, max(total_price)=8811.96), Row(age=24, min(total_price)=133.79, max(total_price)=9004.29)]
# 24/12/01 19:35:28 WARN TaskSetManager: Stage 105 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(age=26, min(unit_price)=179.1, max(unit_price)=1139.67), Row(age=29, min(unit_price)=299.32, max(unit_price)=1118.98), Row(age=65, min(unit_price)=124.12, max(unit_price)=1133.13), Row(age=19, min(unit_price)=870.61, max(unit_price)=1078.74), Row(age=54, min(unit_price)=147.64, max(unit_price)=1131.14), Row(age=22, min(unit_price)=136.76, max(unit_price)=1128.1), Row(age=77, min(unit_price)=124.15, max(unit_price)=1135.67), Row(age=34, min(unit_price)=138.58, max(unit_price)=1134.0), Row(age=50, min(unit_price)=145.28, max(unit_price)=1108.37), Row(age=57, min(unit_price)=143.32, max(unit_price)=1134.28), Row(age=32, min(unit_price)=144.28, max(unit_price)=1132.76), Row(age=43, min(unit_price)=124.7, max(unit_price)=1133.83), Row(age=31, min(unit_price)=127.56, max(unit_price)=1135.71), Row(age=39, min(unit_price)=142.65, max(unit_price)=1133.57), Row(age=25, min(unit_price)=223.14, max(unit_price)=1132.29), Row(age=71, min(unit_price)=206.53, max(unit_price)=1137.83), Row(age=68, min(unit_price)=142.93, max(unit_price)=1139.64), Row(age=72, min(unit_price)=143.09, max(unit_price)=1139.67), Row(age=58, min(unit_price)=131.0, max(unit_price)=1138.58), Row(age=27, min(unit_price)=165.97, max(unit_price)=1136.5), Row(age=63, min(unit_price)=136.32, max(unit_price)=1139.51), Row(age=56, min(unit_price)=129.1, max(unit_price)=1116.42), Row(age=51, min(unit_price)=123.81, max(unit_price)=1137.41), Row(age=52, min(unit_price)=125.99, max(unit_price)=1137.16), Row(age=79, min(unit_price)=134.97, max(unit_price)=1137.81), Row(age=41, min(unit_price)=130.51, max(unit_price)=1122.8), Row(age=28, min(unit_price)=160.46, max(unit_price)=1133.22), Row(age=33, min(unit_price)=140.03, max(unit_price)=1122.26), Row(age=67, min(unit_price)=158.25, max(unit_price)=1130.28), Row(age=48, min(unit_price)=168.26, max(unit_price)=1113.58), Row(age=44, min(unit_price)=124.22, max(unit_price)=1132.84), Row(age=61, min(unit_price)=127.92, max(unit_price)=1127.81), Row(age=37, min(unit_price)=124.85, max(unit_price)=1139.32), Row(age=55, min(unit_price)=127.99, max(unit_price)=1139.55), Row(age=74, min(unit_price)=154.73, max(unit_price)=1105.6), Row(age=62, min(unit_price)=127.51, max(unit_price)=1137.52), Row(age=49, min(unit_price)=150.4, max(unit_price)=1137.74), Row(age=35, min(unit_price)=149.17, max(unit_price)=1137.12), Row(age=80, min(unit_price)=135.04, max(unit_price)=1134.09), Row(age=66, min(unit_price)=137.69, max(unit_price)=1136.48), Row(age=76, min(unit_price)=127.93, max(unit_price)=1102.68), Row(age=36, min(unit_price)=124.65, max(unit_price)=1117.89), Row(age=75, min(unit_price)=169.61, max(unit_price)=1133.03), Row(age=78, min(unit_price)=183.47, max(unit_price)=1126.38), Row(age=69, min(unit_price)=128.18, max(unit_price)=1138.32), Row(age=21, min(unit_price)=126.2, max(unit_price)=1107.37), Row(age=59, min(unit_price)=127.49, max(unit_price)=1128.31), Row(age=38, min(unit_price)=126.01, max(unit_price)=1138.8), Row(age=42, min(unit_price)=123.85, max(unit_price)=1127.17), Row(age=73, min(unit_price)=153.88, max(unit_price)=1135.75), Row(age=30, min(unit_price)=125.62, max(unit_price)=1128.56), Row(age=23, min(unit_price)=124.31, max(unit_price)=1134.57), Row(age=46, min(unit_price)=124.47, max(unit_price)=1139.68), Row(age=20, min(unit_price)=124.51, max(unit_price)=1100.28), Row(age=70, min(unit_price)=132.42, max(unit_price)=1139.57), Row(age=60, min(unit_price)=125.46, max(unit_price)=1138.93), Row(age=40, min(unit_price)=152.99, max(unit_price)=1131.27), Row(age=64, min(unit_price)=124.56, max(unit_price)=1134.19), Row(age=47, min(unit_price)=215.99, max(unit_price)=1138.94), Row(age=53, min(unit_price)=275.19, max(unit_price)=1139.54), Row(age=45, min(unit_price)=145.54, max(unit_price)=1138.93), Row(age=24, min(unit_price)=307.32, max(unit_price)=1128.46)]
# [Row(gender='Female', age=32, min(total_price)=28.36, max(total_price)=8219.16), Row(gender='Male', age=78, min(total_price)=62.88, max(total_price)=9987.69), Row(gender='Female', age=44, min(total_price)=65.17, max(total_price)=9001.28), Row(gender='Male', age=74, min(total_price)=155.29, max(total_price)=8158.27), Row(gender='Female', age=39, min(total_price)=482.05, max(total_price)=6893.91), Row(gender='Male', age=61, min(total_price)=68.76, max(total_price)=10495.26), Row(gender='Male', age=59, min(total_price)=141.69, max(total_price)=7939.94), Row(gender='Female', age=68, min(total_price)=345.0, max(total_price)=11396.8), Row(gender='Female', age=50, min(total_price)=155.61, max(total_price)=7667.14), Row(gender='Female', age=27, min(total_price)=824.7, max(total_price)=6777.59), Row(gender='Female', age=51, min(total_price)=27.15, max(total_price)=8545.02), Row(gender='Female', age=77, min(total_price)=93.28, max(total_price)=7630.14), Row(gender='Female', age=36, min(total_price)=117.61, max(total_price)=5675.04), Row(gender='Female', age=54, min(total_price)=534.88, max(total_price)=6917.78), Row(gender='Female', age=52, min(total_price)=150.96, max(total_price)=11396.8), Row(gender='Male', age=28, min(total_price)=306.43, max(total_price)=8068.06), Row(gender='Male', age=47, min(total_price)=163.48, max(total_price)=11396.8), Row(gender='Male', age=42, min(total_price)=114.51, max(total_price)=10195.57), Row(gender='Female', age=72, min(total_price)=516.7, max(total_price)=9987.47), Row(gender='Male', age=80, min(total_price)=112.97, max(total_price)=4360.61), Row(gender='Female', age=22, min(total_price)=27.63, max(total_price)=8519.85), Row(gender='Male', age=22, min(total_price)=288.49, max(total_price)=3170.51), Row(gender='Male', age=55, min(total_price)=218.84, max(total_price)=11396.8), Row(gender='Male', age=56, min(total_price)=41.75, max(total_price)=11396.8), Row(gender='Female', age=30, min(total_price)=111.7, max(total_price)=7367.7), Row(gender='Female', age=35, min(total_price)=36.32, max(total_price)=8286.73), Row(gender='Male', age=79, min(total_price)=116.42, max(total_price)=8504.02), Row(gender='Male', age=45, min(total_price)=55.41, max(total_price)=7304.83), Row(gender='Male', age=24, min(total_price)=706.68, max(total_price)=7074.43), Row(gender='Female', age=70, min(total_price)=328.06, max(total_price)=9933.12), Row(gender='Female', age=19, min(total_price)=986.51, max(total_price)=6231.91), Row(gender='Female', age=49, min(total_price)=128.06, max(total_price)=10198.84), Row(gender='Female', age=73, min(total_price)=251.71, max(total_price)=9963.78), Row(gender='Female', age=69, min(total_price)=36.64, max(total_price)=10352.66), Row(gender='Male', age=31, min(total_price)=157.49, max(total_price)=8218.8), Row(gender='Female', age=56, min(total_price)=155.23, max(total_price)=6548.75), Row(gender='Male', age=20, min(total_price)=277.7, max(total_price)=4477.33), Row(gender='Male', age=35, min(total_price)=615.94, max(total_price)=7720.16), Row(gender='Male', age=30, min(total_price)=123.82, max(total_price)=4673.24), Row(gender='Male', age=63, min(total_price)=146.84, max(total_price)=7839.1), Row(gender='Female', age=37, min(total_price)=37.77, max(total_price)=9053.51), Row(gender='Female', age=58, min(total_price)=407.34, max(total_price)=10680.56), Row(gender='Male', age=25, min(total_price)=683.04, max(total_price)=7525.99), Row(gender='Male', age=40, min(total_price)=121.95, max(total_price)=5150.94), Row(gender='Female', age=47, min(total_price)=1138.15, max(total_price)=7192.06), Row(gender='Female', age=65, min(total_price)=87.32, max(total_price)=6442.39), Row(gender='Female', age=59, min(total_price)=909.47, max(total_price)=9719.13), Row(gender='Female', age=20, min(total_price)=78.0, max(total_price)=9777.08), Row(gender='Female', age=34, min(total_price)=105.25, max(total_price)=7440.73), Row(gender='Male', age=72, min(total_price)=171.06, max(total_price)=11396.8), Row(gender ...
# 24/12/01 19:35:32 WARN TaskSetManager: Stage 108 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(gender='Female', age=32, min(unit_price)=144.28, max(unit_price)=1122.25), Row(gender='Male', age=78, min(unit_price)=235.41, max(unit_price)=1126.38), Row(gender='Female', age=44, min(unit_price)=141.23, max(unit_price)=1061.25), Row(gender='Male', age=74, min(unit_price)=200.06, max(unit_price)=1105.6), Row(gender='Female', age=39, min(unit_price)=145.19, max(unit_price)=1123.76), Row(gender='Male', age=61, min(unit_price)=141.21, max(unit_price)=1127.81), Row(gender='Male', age=59, min(unit_price)=127.49, max(unit_price)=1128.31), Row(gender='Female', age=68, min(unit_price)=142.93, max(unit_price)=1139.64), Row(gender='Female', age=50, min(unit_price)=145.28, max(unit_price)=1068.29), Row(gender='Female', age=27, min(unit_price)=165.97, max(unit_price)=1107.36), Row(gender='Female', age=51, min(unit_price)=123.81, max(unit_price)=1137.41), Row(gender='Female', age=77, min(unit_price)=129.15, max(unit_price)=1135.67), Row(gender='Female', age=36, min(unit_price)=124.65, max(unit_price)=1007.87), Row(gender='Female', age=54, min(unit_price)=267.67, max(unit_price)=1091.62), Row(gender='Female', age=52, min(unit_price)=158.91, max(unit_price)=1137.16), Row(gender='Male', age=28, min(unit_price)=160.46, max(unit_price)=1095.89), Row(gender='Male', age=47, min(unit_price)=215.99, max(unit_price)=1138.94), Row(gender='Male', age=42, min(unit_price)=123.85, max(unit_price)=1127.17), Row(gender='Female', age=72, min(unit_price)=153.13, max(unit_price)=1136.76), Row(gender='Male', age=80, min(unit_price)=135.04, max(unit_price)=1134.09), Row(gender='Female', age=22, min(unit_price)=136.76, max(unit_price)=1128.1), Row(gender='Male', age=22, min(unit_price)=137.56, max(unit_price)=1025.38), Row(gender='Male', age=55, min(unit_price)=127.99, max(unit_price)=1139.55), Row(gender='Male', age=56, min(unit_price)=135.89, max(unit_price)=1065.31), Row(gender='Female', age=30, min(unit_price)=125.62, max(unit_price)=1128.56), Row(gender='Female', age=35, min(unit_price)=368.29, max(unit_price)=1120.35), Row(gender='Male', age=79, min(unit_price)=164.84, max(unit_price)=1118.64), Row(gender='Male', age=45, min(unit_price)=145.54, max(unit_price)=1138.93), Row(gender='Male', age=24, min(unit_price)=307.32, max(unit_price)=1128.46), Row(gender='Female', age=70, min(unit_price)=158.51, max(unit_price)=1139.57), Row(gender='Female', age=19, min(unit_price)=870.61, max(unit_price)=1078.74), Row(gender='Female', age=49, min(unit_price)=150.4, max(unit_price)=1134.28), Row(gender='Female', age=73, min(unit_price)=166.28, max(unit_price)=1135.75), Row(gender='Female', age=69, min(unit_price)=128.18, max(unit_price)=1138.32), Row(gender='Male', age=31, min(unit_price)=127.56, max(unit_price)=1053.89), Row(gender='Female', age=56, min(unit_price)=129.1, max(unit_price)=1116.42), Row(gender='Male', age=20, min(unit_price)=404.42, max(unit_price)=1077.54), Row(gender='Male', age=35, min(unit_price)=149.17, max(unit_price)=1137.12), Row(gender='Male', age=30, min(unit_price)=127.29, max(unit_price)=899.27), Row(gender='Male', age=63, min(unit_price)=136.32, max(unit_price)=1139.51), Row(gender='Female', age=37, min(unit_price)=124.85, max(unit_price)=1139.04), Row(gender='Female', age=58, min(unit_price)=131.0, max(unit_price)=1131.47), Row(gender='Male', age=25, min(unit_price)=248.81, max(unit_price)=1108.79), Row(gender='Male', age=40, min(unit_price)=254.1, max(unit_price)=1081.08), Row(gender='Female', age=47, min(unit_price)=358.47, max(unit_price)=1009.91), Row(gender='Female', age=65, min(unit_price)=124.12, max(unit_price)=1133.13), Row(gender='Female', age=59, min(unit_price)=423.48, max(unit_price)=1097.73), Row(gender='Female', age=20, min(unit_price)=124.51, max(unit_price)=1100.28), Row(gender='Female', age=34, min(unit_price)=212.43, max(unit_price)=1116.93), Row(gender='Male', age=72, min(unit_price)=143.09, max(unit_price)=1139.67), Row(gender='Female', age=74, min(unit_price)=154.73, max(unit_price)=1103.68), Row(gender='Male', ag ...
# processed in 187.01038499999999 caching=False
# /Users/disarra/hse/python/dz10/spark/lib/python3.8/site-packages/sdv/single_table/base.py:119: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /Users/disarra/hse/python/dz10/spark/lib/python3.8/site-packages/sdv/single_table/base.py:104: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# 24/12/01 19:38:47 WARN TaskSetManager: Stage 111 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# 24/12/01 19:38:50 WARN TaskSetManager: Stage 112 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(gender='Female', min(total_price)=25.88, max(total_price)=11396.8), Row(gender='Male', min(total_price)=21.96, max(total_price)=11396.8)]
# 24/12/01 19:38:50 WARN TaskSetManager: Stage 115 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(gender='Female', min(unit_price)=123.81, max(unit_price)=1139.68), Row(gender='Male', min(unit_price)=123.85, max(unit_price)=1139.67)]
# 24/12/01 19:38:51 WARN TaskSetManager: Stage 118 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(age=26, min(total_price)=754.6, max(total_price)=9026.8), Row(age=29, min(total_price)=407.94, max(total_price)=7546.81), Row(age=65, min(total_price)=87.32, max(total_price)=6887.02), Row(age=19, min(total_price)=105.46, max(total_price)=6611.77), Row(age=54, min(total_price)=286.38, max(total_price)=9822.92), Row(age=22, min(total_price)=27.63, max(total_price)=8519.85), Row(age=77, min(total_price)=51.63, max(total_price)=7630.14), Row(age=34, min(total_price)=105.25, max(total_price)=8927.99), Row(age=50, min(total_price)=155.61, max(total_price)=8839.47), Row(age=57, min(total_price)=190.88, max(total_price)=9969.88), Row(age=32, min(total_price)=28.36, max(total_price)=9601.93), Row(age=43, min(total_price)=463.07, max(total_price)=9534.8), Row(age=31, min(total_price)=36.98, max(total_price)=8218.8), Row(age=39, min(total_price)=202.87, max(total_price)=7198.22), Row(age=25, min(total_price)=114.31, max(total_price)=7538.19), Row(age=71, min(total_price)=265.0, max(total_price)=11396.8), Row(age=68, min(total_price)=294.61, max(total_price)=11396.8), Row(age=72, min(total_price)=171.06, max(total_price)=11396.8), Row(age=58, min(total_price)=118.44, max(total_price)=10680.56), Row(age=27, min(total_price)=824.7, max(total_price)=8764.94), Row(age=63, min(total_price)=146.84, max(total_price)=9519.21), Row(age=56, min(total_price)=41.75, max(total_price)=11396.8), Row(age=51, min(total_price)=27.15, max(total_price)=8545.02), Row(age=52, min(total_price)=87.71, max(total_price)=11396.8), Row(age=79, min(total_price)=38.95, max(total_price)=8600.45), Row(age=41, min(total_price)=381.33, max(total_price)=7380.3), Row(age=28, min(total_price)=154.54, max(total_price)=8068.06), Row(age=33, min(total_price)=25.88, max(total_price)=9451.08), Row(age=67, min(total_price)=33.73, max(total_price)=8857.35), Row(age=48, min(total_price)=85.17, max(total_price)=10852.25), Row(age=44, min(total_price)=21.96, max(total_price)=9001.28), Row(age=61, min(total_price)=68.76, max(total_price)=10495.26), Row(age=37, min(total_price)=37.77, max(total_price)=11396.8), Row(age=55, min(total_price)=57.88, max(total_price)=11396.8), Row(age=74, min(total_price)=55.8, max(total_price)=8158.27), Row(age=62, min(total_price)=326.52, max(total_price)=10588.37), Row(age=49, min(total_price)=128.06, max(total_price)=10938.94), Row(age=35, min(total_price)=36.32, max(total_price)=8286.73), Row(age=80, min(total_price)=112.97, max(total_price)=4658.29), Row(age=66, min(total_price)=118.58, max(total_price)=9572.95), Row(age=76, min(total_price)=110.53, max(total_price)=10767.48), Row(age=36, min(total_price)=117.61, max(total_price)=11396.8), Row(age=75, min(total_price)=227.81, max(total_price)=9002.88), Row(age=78, min(total_price)=62.88, max(total_price)=9987.69), Row(age=69, min(total_price)=36.64, max(total_price)=10950.05), Row(age=21, min(total_price)=27.03, max(total_price)=8580.62), Row(age=59, min(total_price)=141.69, max(total_price)=9719.13), Row(age=38, min(total_price)=121.99, max(total_price)=9426.53), Row(age=42, min(total_price)=114.51, max(total_price)=10195.57), Row(age=73, min(total_price)=251.71, max(total_price)=9963.78), Row(age=30, min(total_price)=111.7, max(total_price)=7367.7), Row(age=23, min(total_price)=323.85, max(total_price)=10677.81), Row(age=46, min(total_price)=72.6, max(total_price)=11396.8), Row(age=20, min(total_price)=78.0, max(total_price)=9777.08), Row(age=70, min(total_price)=79.99, max(total_price)=9933.12), Row(age=60, min(total_price)=22.81, max(total_price)=11396.8), Row(age=40, min(total_price)=76.38, max(total_price)=9571.2), Row(age=64, min(total_price)=44.74, max(total_price)=9172.57), Row(age=47, min(total_price)=163.48, max(total_price)=11396.8), Row(age=53, min(total_price)=99.34, max(total_price)=7179.24), Row(age=45, min(total_price)=55.41, max(total_price)=8811.96), Row(age=24, min(total_price)=133.79, max(total_price)=9004.29)]
# 24/12/01 19:38:51 WARN TaskSetManager: Stage 121 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(age=26, min(unit_price)=179.1, max(unit_price)=1139.67), Row(age=29, min(unit_price)=299.32, max(unit_price)=1118.98), Row(age=65, min(unit_price)=124.12, max(unit_price)=1133.13), Row(age=19, min(unit_price)=870.61, max(unit_price)=1078.74), Row(age=54, min(unit_price)=147.64, max(unit_price)=1131.14), Row(age=22, min(unit_price)=136.76, max(unit_price)=1128.1), Row(age=77, min(unit_price)=124.15, max(unit_price)=1135.67), Row(age=34, min(unit_price)=138.58, max(unit_price)=1134.0), Row(age=50, min(unit_price)=145.28, max(unit_price)=1108.37), Row(age=57, min(unit_price)=143.32, max(unit_price)=1134.28), Row(age=32, min(unit_price)=144.28, max(unit_price)=1132.76), Row(age=43, min(unit_price)=124.7, max(unit_price)=1133.83), Row(age=31, min(unit_price)=127.56, max(unit_price)=1135.71), Row(age=39, min(unit_price)=142.65, max(unit_price)=1133.57), Row(age=25, min(unit_price)=223.14, max(unit_price)=1132.29), Row(age=71, min(unit_price)=206.53, max(unit_price)=1137.83), Row(age=68, min(unit_price)=142.93, max(unit_price)=1139.64), Row(age=72, min(unit_price)=143.09, max(unit_price)=1139.67), Row(age=58, min(unit_price)=131.0, max(unit_price)=1138.58), Row(age=27, min(unit_price)=165.97, max(unit_price)=1136.5), Row(age=63, min(unit_price)=136.32, max(unit_price)=1139.51), Row(age=56, min(unit_price)=129.1, max(unit_price)=1116.42), Row(age=51, min(unit_price)=123.81, max(unit_price)=1137.41), Row(age=52, min(unit_price)=125.99, max(unit_price)=1137.16), Row(age=79, min(unit_price)=134.97, max(unit_price)=1137.81), Row(age=41, min(unit_price)=130.51, max(unit_price)=1122.8), Row(age=28, min(unit_price)=160.46, max(unit_price)=1133.22), Row(age=33, min(unit_price)=140.03, max(unit_price)=1122.26), Row(age=67, min(unit_price)=158.25, max(unit_price)=1130.28), Row(age=48, min(unit_price)=168.26, max(unit_price)=1113.58), Row(age=44, min(unit_price)=124.22, max(unit_price)=1132.84), Row(age=61, min(unit_price)=127.92, max(unit_price)=1127.81), Row(age=37, min(unit_price)=124.85, max(unit_price)=1139.32), Row(age=55, min(unit_price)=127.99, max(unit_price)=1139.55), Row(age=74, min(unit_price)=154.73, max(unit_price)=1105.6), Row(age=62, min(unit_price)=127.51, max(unit_price)=1137.52), Row(age=49, min(unit_price)=150.4, max(unit_price)=1137.74), Row(age=35, min(unit_price)=149.17, max(unit_price)=1137.12), Row(age=80, min(unit_price)=135.04, max(unit_price)=1134.09), Row(age=66, min(unit_price)=137.69, max(unit_price)=1136.48), Row(age=76, min(unit_price)=127.93, max(unit_price)=1102.68), Row(age=36, min(unit_price)=124.65, max(unit_price)=1117.89), Row(age=75, min(unit_price)=169.61, max(unit_price)=1133.03), Row(age=78, min(unit_price)=183.47, max(unit_price)=1126.38), Row(age=69, min(unit_price)=128.18, max(unit_price)=1138.32), Row(age=21, min(unit_price)=126.2, max(unit_price)=1107.37), Row(age=59, min(unit_price)=127.49, max(unit_price)=1128.31), Row(age=38, min(unit_price)=126.01, max(unit_price)=1138.8), Row(age=42, min(unit_price)=123.85, max(unit_price)=1127.17), Row(age=73, min(unit_price)=153.88, max(unit_price)=1135.75), Row(age=30, min(unit_price)=125.62, max(unit_price)=1128.56), Row(age=23, min(unit_price)=124.31, max(unit_price)=1134.57), Row(age=46, min(unit_price)=124.47, max(unit_price)=1139.68), Row(age=20, min(unit_price)=124.51, max(unit_price)=1100.28), Row(age=70, min(unit_price)=132.42, max(unit_price)=1139.57), Row(age=60, min(unit_price)=125.46, max(unit_price)=1138.93), Row(age=40, min(unit_price)=152.99, max(unit_price)=1131.27), Row(age=64, min(unit_price)=124.56, max(unit_price)=1134.19), Row(age=47, min(unit_price)=215.99, max(unit_price)=1138.94), Row(age=53, min(unit_price)=275.19, max(unit_price)=1139.54), Row(age=45, min(unit_price)=145.54, max(unit_price)=1138.93), Row(age=24, min(unit_price)=307.32, max(unit_price)=1128.46)]
# 24/12/01 19:38:52 WARN TaskSetManager: Stage 124 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(gender='Female', age=32, min(total_price)=28.36, max(total_price)=8219.16), Row(gender='Male', age=78, min(total_price)=62.88, max(total_price)=9987.69), Row(gender='Female', age=44, min(total_price)=65.17, max(total_price)=9001.28), Row(gender='Male', age=74, min(total_price)=155.29, max(total_price)=8158.27), Row(gender='Female', age=39, min(total_price)=482.05, max(total_price)=6893.91), Row(gender='Male', age=61, min(total_price)=68.76, max(total_price)=10495.26), Row(gender='Male', age=59, min(total_price)=141.69, max(total_price)=7939.94), Row(gender='Female', age=68, min(total_price)=345.0, max(total_price)=11396.8), Row(gender='Female', age=50, min(total_price)=155.61, max(total_price)=7667.14), Row(gender='Female', age=27, min(total_price)=824.7, max(total_price)=6777.59), Row(gender='Female', age=51, min(total_price)=27.15, max(total_price)=8545.02), Row(gender='Female', age=77, min(total_price)=93.28, max(total_price)=7630.14), Row(gender='Female', age=36, min(total_price)=117.61, max(total_price)=5675.04), Row(gender='Female', age=54, min(total_price)=534.88, max(total_price)=6917.78), Row(gender='Female', age=52, min(total_price)=150.96, max(total_price)=11396.8), Row(gender='Male', age=28, min(total_price)=306.43, max(total_price)=8068.06), Row(gender='Male', age=47, min(total_price)=163.48, max(total_price)=11396.8), Row(gender='Male', age=42, min(total_price)=114.51, max(total_price)=10195.57), Row(gender='Female', age=72, min(total_price)=516.7, max(total_price)=9987.47), Row(gender='Male', age=80, min(total_price)=112.97, max(total_price)=4360.61), Row(gender='Female', age=22, min(total_price)=27.63, max(total_price)=8519.85), Row(gender='Male', age=22, min(total_price)=288.49, max(total_price)=3170.51), Row(gender='Male', age=55, min(total_price)=218.84, max(total_price)=11396.8), Row(gender='Male', age=56, min(total_price)=41.75, max(total_price)=11396.8), Row(gender='Female', age=30, min(total_price)=111.7, max(total_price)=7367.7), Row(gender='Female', age=35, min(total_price)=36.32, max(total_price)=8286.73), Row(gender='Male', age=79, min(total_price)=116.42, max(total_price)=8504.02), Row(gender='Male', age=45, min(total_price)=55.41, max(total_price)=7304.83), Row(gender='Male', age=24, min(total_price)=706.68, max(total_price)=7074.43), Row(gender='Female', age=70, min(total_price)=328.06, max(total_price)=9933.12), Row(gender='Female', age=19, min(total_price)=986.51, max(total_price)=6231.91), Row(gender='Female', age=49, min(total_price)=128.06, max(total_price)=10198.84), Row(gender='Female', age=73, min(total_price)=251.71, max(total_price)=9963.78), Row(gender='Female', age=69, min(total_price)=36.64, max(total_price)=10352.66), Row(gender='Male', age=31, min(total_price)=157.49, max(total_price)=8218.8), Row(gender='Female', age=56, min(total_price)=155.23, max(total_price)=6548.75), Row(gender='Male', age=20, min(total_price)=277.7, max(total_price)=4477.33), Row(gender='Male', age=35, min(total_price)=615.94, max(total_price)=7720.16), Row(gender='Male', age=30, min(total_price)=123.82, max(total_price)=4673.24), Row(gender='Male', age=63, min(total_price)=146.84, max(total_price)=7839.1), Row(gender='Female', age=37, min(total_price)=37.77, max(total_price)=9053.51), Row(gender='Female', age=58, min(total_price)=407.34, max(total_price)=10680.56), Row(gender='Male', age=25, min(total_price)=683.04, max(total_price)=7525.99), Row(gender='Male', age=40, min(total_price)=121.95, max(total_price)=5150.94), Row(gender='Female', age=47, min(total_price)=1138.15, max(total_price)=7192.06), Row(gender='Female', age=65, min(total_price)=87.32, max(total_price)=6442.39), Row(gender='Female', age=59, min(total_price)=909.47, max(total_price)=9719.13), Row(gender='Female', age=20, min(total_price)=78.0, max(total_price)=9777.08), Row(gender='Female', age=34, min(total_price)=105.25, max(total_price)=7440.73), Row(gender='Male', age=72, min(total_price)=171.06, max(total_price)=11396.8), Row(gender ...
# 24/12/01 19:38:52 WARN TaskSetManager: Stage 127 contains a task of very large size (71514 KiB). The maximum recommended task size is 1000 KiB.
# [Row(gender='Female', age=32, min(unit_price)=144.28, max(unit_price)=1122.25), Row(gender='Male', age=78, min(unit_price)=235.41, max(unit_price)=1126.38), Row(gender='Female', age=44, min(unit_price)=141.23, max(unit_price)=1061.25), Row(gender='Male', age=74, min(unit_price)=200.06, max(unit_price)=1105.6), Row(gender='Female', age=39, min(unit_price)=145.19, max(unit_price)=1123.76), Row(gender='Male', age=61, min(unit_price)=141.21, max(unit_price)=1127.81), Row(gender='Male', age=59, min(unit_price)=127.49, max(unit_price)=1128.31), Row(gender='Female', age=68, min(unit_price)=142.93, max(unit_price)=1139.64), Row(gender='Female', age=50, min(unit_price)=145.28, max(unit_price)=1068.29), Row(gender='Female', age=27, min(unit_price)=165.97, max(unit_price)=1107.36), Row(gender='Female', age=51, min(unit_price)=123.81, max(unit_price)=1137.41), Row(gender='Female', age=77, min(unit_price)=129.15, max(unit_price)=1135.67), Row(gender='Female', age=36, min(unit_price)=124.65, max(unit_price)=1007.87), Row(gender='Female', age=54, min(unit_price)=267.67, max(unit_price)=1091.62), Row(gender='Female', age=52, min(unit_price)=158.91, max(unit_price)=1137.16), Row(gender='Male', age=28, min(unit_price)=160.46, max(unit_price)=1095.89), Row(gender='Male', age=47, min(unit_price)=215.99, max(unit_price)=1138.94), Row(gender='Male', age=42, min(unit_price)=123.85, max(unit_price)=1127.17), Row(gender='Female', age=72, min(unit_price)=153.13, max(unit_price)=1136.76), Row(gender='Male', age=80, min(unit_price)=135.04, max(unit_price)=1134.09), Row(gender='Female', age=22, min(unit_price)=136.76, max(unit_price)=1128.1), Row(gender='Male', age=22, min(unit_price)=137.56, max(unit_price)=1025.38), Row(gender='Male', age=55, min(unit_price)=127.99, max(unit_price)=1139.55), Row(gender='Male', age=56, min(unit_price)=135.89, max(unit_price)=1065.31), Row(gender='Female', age=30, min(unit_price)=125.62, max(unit_price)=1128.56), Row(gender='Female', age=35, min(unit_price)=368.29, max(unit_price)=1120.35), Row(gender='Male', age=79, min(unit_price)=164.84, max(unit_price)=1118.64), Row(gender='Male', age=45, min(unit_price)=145.54, max(unit_price)=1138.93), Row(gender='Male', age=24, min(unit_price)=307.32, max(unit_price)=1128.46), Row(gender='Female', age=70, min(unit_price)=158.51, max(unit_price)=1139.57), Row(gender='Female', age=19, min(unit_price)=870.61, max(unit_price)=1078.74), Row(gender='Female', age=49, min(unit_price)=150.4, max(unit_price)=1134.28), Row(gender='Female', age=73, min(unit_price)=166.28, max(unit_price)=1135.75), Row(gender='Female', age=69, min(unit_price)=128.18, max(unit_price)=1138.32), Row(gender='Male', age=31, min(unit_price)=127.56, max(unit_price)=1053.89), Row(gender='Female', age=56, min(unit_price)=129.1, max(unit_price)=1116.42), Row(gender='Male', age=20, min(unit_price)=404.42, max(unit_price)=1077.54), Row(gender='Male', age=35, min(unit_price)=149.17, max(unit_price)=1137.12), Row(gender='Male', age=30, min(unit_price)=127.29, max(unit_price)=899.27), Row(gender='Male', age=63, min(unit_price)=136.32, max(unit_price)=1139.51), Row(gender='Female', age=37, min(unit_price)=124.85, max(unit_price)=1139.04), Row(gender='Female', age=58, min(unit_price)=131.0, max(unit_price)=1131.47), Row(gender='Male', age=25, min(unit_price)=248.81, max(unit_price)=1108.79), Row(gender='Male', age=40, min(unit_price)=254.1, max(unit_price)=1081.08), Row(gender='Female', age=47, min(unit_price)=358.47, max(unit_price)=1009.91), Row(gender='Female', age=65, min(unit_price)=124.12, max(unit_price)=1133.13), Row(gender='Female', age=59, min(unit_price)=423.48, max(unit_price)=1097.73), Row(gender='Female', age=20, min(unit_price)=124.51, max(unit_price)=1100.28), Row(gender='Female', age=34, min(unit_price)=212.43, max(unit_price)=1116.93), Row(gender='Male', age=72, min(unit_price)=143.09, max(unit_price)=1139.67), Row(gender='Female', age=74, min(unit_price)=154.73, max(unit_price)=1103.68), Row(gender='Male', ag ...
# processed in 182.24422300000003 caching=True

# %%
spark.stop()
